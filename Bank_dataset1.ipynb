# %% [markdown]
# <a href="https://colab.research.google.com/github/oykudurmaz/bank_dat/blob/main/Bank_dataset1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
bank_dataset = pd.read_csv('/content/data.csv')

# %%
bank_dataset.head()
# Out:
#    Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0         1                                           0.370594
# 1         1                                           0.464291
# 2         1                                           0.426071
# 3         1                                           0.399844
# 4         1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
bank_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt                                                  6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
bank_dataset.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
bank_dataset['Bankrupt'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt, dtype: int64

# %%
bankrupt = bank_dataset[bank_dataset.Bankrupt == 1]
nicht_bankrupt = bank_dataset[bank_dataset.Bankrupt == 0]

# %%
bank_dataset.groupby('Bankrupt').mean()
# Out:
#            ROA(C) before interest and depreciation before interest  \
# Bankrupt
# 0                                                  0.508069
# 1                                                  0.418503
#
#            ROA(A) before interest and % after tax  \
# Bankrupt
# 0                                        0.562015
# 1                                        0.456947
#
#            ROA(B) before interest and depreciation after tax  \
# Bankrupt
# 0                                                  0.556659
# 1                                                  0.461483
#
#            Operating Gross Margin   Realized Sales Gross Margin  \
# Bankrupt
# 0                        0.608257                      0.608237
# 1                        0.598670                      0.598717
#
#            Operating Profit Rate   Pre-tax net Interest Rate  \
# Bankrupt
# 0                       0.998756                     0.79721
# ...

# %%
nicht_bankrupt_sample = nicht_bankrupt.sample(n=220)

# %%
new_dataset = pd.concat([nicht_bankrupt_sample, bankrupt], axis=0)

# %%
new_dataset.head()
# Out:
#       Bankrupt   ROA(C) before interest and depreciation before interest  \
# 3853         0                                           0.535758
# 2845         0                                           0.529957
# 981          0                                           0.484035
# 5699         0                                           0.588310
# 2799         0                                           0.613562
#
#        ROA(A) before interest and % after tax  \
# 3853                                 0.575229
# 2845                                 0.587167
# 981                                  0.541594
# 5699                                 0.632523
# 2799                                 0.665013
#
#        ROA(B) before interest and depreciation after tax  \
# 3853                                           0.585256
# 2845                                           0.578778
# 981                                            0.543284
# ...

# %%
new_dataset['Bankrupt'].value_counts()
# Out:
# 0    220
# 1    220
# Name: Bankrupt, dtype: int64

# %%
new_dataset.groupby('Bankrupt').mean()
# Out:
#            ROA(C) before interest and depreciation before interest  \
# Bankrupt
# 0                                                  0.510092
# 1                                                  0.418503
#
#            ROA(A) before interest and % after tax  \
# Bankrupt
# 0                                        0.563768
# 1                                        0.456947
#
#            ROA(B) before interest and depreciation after tax  \
# Bankrupt
# 0                                                  0.558009
# 1                                                  0.461483
#
#            Operating Gross Margin   Realized Sales Gross Margin  \
# Bankrupt
# 0                        0.608264                      0.608223
# 1                        0.598670                      0.598717
#
#            Operating Profit Rate   Pre-tax net Interest Rate  \
# Bankrupt
# 0                       0.999023                    0.797474
# ...

# %%
X = new_dataset.drop(columns='Bankrupt', axis=1)
Y = new_dataset['Bankrupt']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (440, 95) (352, 95) (88, 95)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on traning is : ', training_data_accuracy)
# Out:
# Accuracy on traning is :  0.6534090909090909

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.5909090909090909
